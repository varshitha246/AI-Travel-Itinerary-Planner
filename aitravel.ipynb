# %%
# !pip install flask flask_cors requests streamlit
# Out:
# Requirement already satisfied: flask in c:\users\varsh\appdata\roaming\python\python312\site-packages (3.1.0)
# Requirement already satisfied: flask_cors in c:\users\varsh\appdata\roaming\python\python312\site-packages (5.0.0)
# Requirement already satisfied: requests in c:\users\varsh\appdata\roaming\python\python312\site-packages (2.32.3)
# Requirement already satisfied: streamlit in c:\users\varsh\appdata\roaming\python\python312\site-packages (1.42.1)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from flask) (8.1.7)
# Requirement already satisfied: blinker>=1.9 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from flask) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from streamlit) (4.25.6)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from streamlit) (19.0.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from altair<6,>=4.0->streamlit) (1.27.1)
# Requirement already satisfied: colorama in c:\users\varsh\appdata\roaming\python\python312\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from Jinja2>=3.1.2->flask) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from rich<14,>=10.14.0->streamlit) (2.19.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\varsh\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %%
# %%writefile travel_itinerary1.py

from flask import Flask, request, jsonify
from flask_cors import CORS
import requests
import random

app = Flask(__name__)
CORS(app)

# API Keys
OPENWEATHER_API_KEY = "8fc7ca2e2fd43e83d0f5f840922ab555"
SPOONACULAR_API_KEY = "91d3bf9798ee471d8f1713142f2817d5"
GEOAPIFY_API_KEY = "74ea38e3e82649ab8148339aab1c070a"

# Famous destinations database
FAMOUS_CITIES = {
    # Global Cities
    "Paris": {
        "landmarks": ["Eiffel Tower", "Louvre Museum", "Notre-Dame Cathedral", "Champs-Élysées", "Montmartre"],
        "foods": ["Croissant", "Baguette", "Escargot", "Boeuf Bourguignon", "Macarons"]
    },
    "New York": {
        "landmarks": ["Statue of Liberty", "Times Square", "Central Park", "Empire State Building", "Broadway"],
        "foods": ["New York Pizza", "Bagel with Lox", "Cheesecake", "Pastrami Sandwich", "Hot Dog"]
    },
    "Tokyo": {
        "landmarks": ["Shibuya Crossing", "Tokyo Tower", "Senso-ji Temple", "Meiji Shrine", "Akihabara"],
        "foods": ["Sushi", "Ramen", "Tempura", "Okonomiyaki", "Takoyaki"]
    },
    # Indian Cities
    "Delhi": {
        "landmarks": ["Red Fort", "India Gate", "Qutub Minar", "Lotus Temple", "Chandni Chowk"],
        "foods": ["Butter Chicken", "Chole Bhature", "Paratha", "Kebabs", "Jalebi"]
    },
    "Mumbai": {
        "landmarks": ["Gateway of India", "Marine Drive", "Elephanta Caves", "Chhatrapati Shivaji Terminus", "Juhu Beach"],
        "foods": ["Vada Pav", "Pav Bhaji", "Bombay Sandwich", "Seafood", "Misal Pav"]
    },
    "Bangalore": {
        "landmarks": ["Bangalore Palace", "Lalbagh Botanical Garden", "Cubbon Park", "Vidhana Soudha", "ISKCON Temple"],
        "foods": ["Masala Dosa", "Bisi Bele Bath", "Ragi Mudde", "Mysore Pak", "Filter Coffee"]
    },
    # Add more cities as needed
}

def get_weather(city):
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={OPENWEATHER_API_KEY}&units=metric"
    response = requests.get(url).json()
    if 'main' in response:
        return {
            "temperature": response["main"].get("temp", "N/A"),
            "conditions": response["weather"][0].get("description", "N/A") if response.get("weather") else "N/A",
            "humidity": response["main"].get("humidity", "N/A")
        }
    return {"error": "Weather data not available"}

def get_wikipedia_info(city):
    url = f"https://en.wikipedia.org/api/rest_v1/page/summary/{city}"
    response = requests.get(url).json()
    return {
        "description": response.get("extract", "No description available"),
        "image": response.get("thumbnail", {}).get("source", "") if response.get("thumbnail") else ""
    }

def get_restaurants(city, budget="Standard"):
    # First check if we have famous local foods for this city
    local_foods = FAMOUS_CITIES.get(city, {}).get("foods", [])
    
    url = f"https://api.spoonacular.com/food/restaurants/search?query={city}&apiKey={SPOONACULAR_API_KEY}"
    try:
        response = requests.get(url).json()
        restaurants = response.get("restaurants", [])
        
        # Enhance restaurant data with local food specialties
        for restaurant in restaurants:
            if local_foods:
                restaurant["specialty"] = random.choice(local_foods)
        
        # Filter by budget
        if budget == "Economy":
            restaurants = [r for r in restaurants if r.get("price_range", "$$$$") in ("$", "$$")]
        elif budget == "Luxury":
            restaurants = [r for r in restaurants if r.get("price_range", "$") in ("$$$", "$$$$")]
        
        return restaurants[:10]
    except:
        # Fallback to local food specialties if API fails
        return [{"name": f"Local {food} Spot", "specialty": food} for food in local_foods[:5]]

def get_places(city, interests=None):
    if interests is None:
        interests = []
    
    # First check if we have famous landmarks for this city
    landmarks = FAMOUS_CITIES.get(city, {}).get("landmarks", [])
    
    categories = []
    if "Adventure" in interests:
        categories.extend(["adventure", "sport"])
    if "Culture" in interests:
        categories.extend(["cultural", "historic", "religion"])
    if "Nature" in interests:
        categories.extend(["natural", "national_park"])
    if "Shopping" in interests:
        categories.append("commercial")
    if not categories:
        categories = ["tourism"]
    
    all_places = []
    for category in set(categories):
        url = f"https://api.geoapify.com/v2/places?categories={category}&filter=place:{city}&limit=20&apiKey={GEOAPIFY_API_KEY}"
        try:
            response = requests.get(url).json()
            all_places.extend(response.get("features", []))
        except:
            continue
    
    # Add famous landmarks first
    for landmark in landmarks:
        all_places.insert(0, {
            "properties": {
                "name": landmark,
                "categories": {"name": "Famous Landmark"},
                "address_line2": city
            }
        })
    
    # Remove duplicates
    unique_places = []
    seen_names = set()
    for place in all_places:
        name = place.get("properties", {}).get("name")
        if name and name not in seen_names:
            unique_places.append(place)
            seen_names.add(name)
    
    return unique_places[:15]

def generate_daily_activities(day, city, attractions, restaurants, interests):
    landmarks = FAMOUS_CITIES.get(city, {}).get("landmarks", [])
    foods = FAMOUS_CITIES.get(city, {}).get("foods", [])
    
    # Morning activities
    if landmarks:
        morning = f"Visit {random.choice(landmarks)}"
    elif "Adventure" in interests:
        morning = random.choice([
            "Hiking at a scenic trail",
            "Water sports at a local spot",
            "Cycling tour around the city"
        ])
    else:
        morning = random.choice([
            "Explore the city center",
            "Walking tour of main sights",
            "Visit local markets"
        ])
    
    # Afternoon activities
    if len(attractions) > 1:
        attraction_names = [a.get("properties", {}).get("name") for a in attractions if a.get("properties", {}).get("name")]
        if attraction_names:
            afternoon = f"Explore {random.choice(attraction_names)}"
        else:
            afternoon = random.choice([
                "Visit a museum or gallery",
                "Discover hidden local gems",
                "Relax at a park or garden"
            ])
    else:
        afternoon = random.choice([
            "Visit a museum or gallery",
            "Discover hidden local gems",
            "Relax at a park or garden"
        ])
    
    # Evening activities
    evening_options = []
    if "Food" in interests and foods:
        evening_options.append(f"Try famous local {random.choice(foods)}")
    evening_options.extend([
        "Enjoy a local performance or show",
        "Relax at a rooftop bar with city views",
        "Take a sunset cruise or walk"
    ])
    evening = random.choice(evening_options)
    
    # Lunch recommendation
    lunch = "Try a popular local dish"
    if restaurants:
        restaurant = random.choice(restaurants)
        specialty = restaurant.get("specialty")
        if specialty:
            lunch = f"Lunch at {restaurant.get('name', 'a local restaurant')} - try their {specialty}"
        else:
            lunch = f"Lunch at {restaurant.get('name', 'a local restaurant')}"
    
    return {
        "day": day,
        "morning": morning,
        "lunch": lunch,
        "afternoon": afternoon,
        "evening": evening
    }

@app.route("/generate_itinerary", methods=["POST"])
def generate_itinerary():
    data = request.json
    city = data.get("city")
    days = data.get("days", 3)
    budget = data.get("budget", "Standard")
    interests = data.get("interests", [])

    if not city:
        return jsonify({"error": "City is required"}), 400

    weather = get_weather(city)
    description = get_wikipedia_info(city)
    restaurants = get_restaurants(city, budget)
    attractions = get_places(city, interests)

    itinerary = []
    for day in range(1, days + 1):
        itinerary.append(generate_daily_activities(day, city, attractions, restaurants, interests))

    response = {
        "weather": weather,
        "description": description.get("description", ""),
        "image": description.get("image", ""),
        "restaurants": restaurants,
        "attractions": [attraction.get("properties", {}) for attraction in attractions],
        "itinerary": itinerary,
        "local_specialties": FAMOUS_CITIES.get(city, {}).get("foods", []),
        "famous_landmarks": FAMOUS_CITIES.get(city, {}).get("landmarks", [])
    }
    return jsonify(response)

if __name__ == "__main__":
    app.run(debug=True)
# Out:
# Overwriting travel_itinerary1.py

# %%
# %%writefile travel_frontend.py
import streamlit as st
import requests
import datetime
from PIL import Image
import io
import base64
import urllib.request

API_URL = "http://127.0.0.1:5000/generate_itinerary"

def load_image_from_url(url):
    try:
        with urllib.request.urlopen(url) as response:
            img = Image.open(io.BytesIO(response.read()))
            return img
    except:
        return None

def main():
    st.title("🌍 AI Travel Itinerary Planner")
    st.markdown("""
    <style>
    .day-card {
        border-radius: 10px;
        padding: 15px;
        margin: 10px 0;
        background-color: #f0f2f6;
        box-shadow: 0 2px 5px rgba(0,0,0,0.1);
    }
    .specialty-card {
        border-left: 4px solid #FF4B4B;
        padding: 10px;
        margin: 5px 0;
        background-color: white;
    }
    .landmark-card {
        border-left: 4px solid #1C83E1;
        padding: 10px;
        margin: 5px 0;
        background-color: white;
    }
    </style>
    """, unsafe_allow_html=True)

    # Popular cities quick select
    popular_cities = st.multiselect("Or select from popular destinations:", 
                                  ["Paris", "New York", "Tokyo", 
                                   "Delhi", "Mumbai", "Bangalore",
                                   "London", "Dubai", "Bangkok",
                                   "Jaipur", "Goa", "Kolkata"])

    if popular_cities:
        destination = st.text_input("Enter Destination:", value=popular_cities[0])
    else:
        destination = st.text_input("Enter Destination:", placeholder="e.g., Paris, Tokyo, Delhi")

    col1, col2 = st.columns(2)
    with col1:
        days = st.slider("Trip Duration (Days):", 1, 30, 3)
    with col2:
        start_date = st.date_input("Start Date:", datetime.date.today())
        budget = st.selectbox("Budget Category:", ["Economy", "Standard", "Luxury"])

    interests = st.multiselect("Select Interests:", 
                              ["Food", "Adventure", "Culture", "Nature", "Shopping", "History", "Relaxation"],
                              default=["Culture", "Food"])

    if st.button("✨ Generate Itinerary", type="primary"):
        if destination:
            with st.spinner("Creating your perfect itinerary..."):
                response = requests.post(API_URL, json={
                    "city": destination,
                    "days": days,
                    "budget": budget,
                    "interests": interests
                })
                
                if response.status_code == 200:
                    data = response.json()
                    
                    # Destination header
                    st.subheader(f"✈️ Your {days}-Day Trip to {destination}")
                    
                    col1, col2 = st.columns([1, 2])
                    with col1:
                        if data.get("image"):
                            img = load_image_from_url(data["image"])
                            if img:
                                st.image(img, caption=destination, width=200)
                    
                    with col2:
                        st.write(f"**Weather:** {data['weather'].get('temperature', 'N/A')}°C, {data['weather'].get('conditions', 'N/A')}")
                        st.write(f"**Humidity:** {data['weather'].get('humidity', 'N/A')}%")
                        st.write(f"**About {destination}:** {data['description']}")
                    
                    # Local Specialties
                    if data.get("local_specialties"):
                        st.markdown("### 🍜 Must-Try Local Foods")
                        for food in data["local_specialties"]:
                            st.markdown(f"""
                            <div class="specialty-card">
                                <h4>{food}</h4>
                                <p>Famous local specialty of {destination}</p>
                            </div>
                            """, unsafe_allow_html=True)
                    
                    # Famous Landmarks
                    if data.get("famous_landmarks"):
                        st.markdown("### 🗼 Iconic Landmarks")
                        for landmark in data["famous_landmarks"]:
                            st.markdown(f"""
                            <div class="landmark-card">
                                <h4>{landmark}</h4>
                                <p>Iconic landmark of {destination}</p>
                            </div>
                            """, unsafe_allow_html=True)
                    
                    # Itinerary
                    st.markdown("### 📅 Daily Itinerary")
                    for day in data["itinerary"]:
                        with st.expander(f"Day {day['day']}: {start_date + datetime.timedelta(days=day['day']-1)}", expanded=True):
                            st.markdown(f"""
                            <div class="day-card">
                                <h4>🌅 Morning</h4>
                                <p>{day['morning']}</p>
                                
                                <h4>🍽 Lunch</h4>
                                <p>{day['lunch']}</p>
                                
                                <h4>☀️ Afternoon</h4>
                                <p>{day['afternoon']}</p>
                                
                                <h4>🌇 Evening</h4>
                                <p>{day['evening']}</p>
                            </div>
                            """, unsafe_allow_html=True)
                    
                    # Restaurants
                    if data.get("restaurants"):
                        st.markdown("### 🍽 Recommended Restaurants")
                        for i, restaurant in enumerate(data["restaurants"][:5]):
                            st.markdown(f"""
                            <div class="specialty-card">
                                <h4>{restaurant.get('name', 'Restaurant')}</h4>
                                <p>📍 {restaurant.get('address', 'Address not available')}</p>
                                <p>💰 {restaurant.get('price_range', 'Price not available')}</p>
                                {f"<p>🍴 Specialty: {restaurant.get('specialty', 'Local cuisine')}</p>" if restaurant.get('specialty') else ""}
                            </div>
                            """, unsafe_allow_html=True)
                    
                    # Attractions
                    if data.get("attractions"):
                        st.markdown("### 🏛 Must-Visit Attractions")
                        for i, attraction in enumerate(data["attractions"][:5]):
                            st.markdown(f"""
                            <div class="landmark-card">
                                <h4>{attraction.get('name', 'Attraction')}</h4>
                                <p>📍 {attraction.get('address_line2', attraction.get('formatted', 'Address not available'))}</p>
                                <p>🏷 {attraction.get('categories', {}).get('name', 'Category not available')}</p>
                            </div>
                            """, unsafe_allow_html=True)
                else:
                    st.error("Failed to fetch itinerary. Please try again.")
        else:
            st.error("Please enter a destination!")

if __name__ == "__main__":
    main()
# Out:
# Overwriting travel_frontend.py
